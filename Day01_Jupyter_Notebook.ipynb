# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %% [markdown]
# ### Observation
# - our data consists of 73268 rows and 79 columns.
# - to display all the columns--

# %%
#Let's start work with columns
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %% [markdown]
# 1. Numbered item
# 1. Numbered item

# %% [markdown]
# 1. Numbered item
#      1. Substep

# %% [markdown]
# #### we can see that our column name consits of camel case letters in the first step we will try to convert all the column names in smaller letters

# %%
#now we will remove the _ in the column name
df.columns=df.columns.str.replace('_', '', regex=True)

# %%
df.columns=df.columns.str.lower()

# %%
df.head(2)
# Out:
#    responseid                      mainbranch           employment  \
# 0           1                   None of these                  NaN
# 1           2  I am a developer by profession  Employed, full-time
#
#      remotework                          codingactivities edlevel learncode  \
# 0           NaN                                       NaN     NaN       NaN
# 1  Fully remote  Hobby;Contribute to open-source projects     NaN       NaN
#
#   learncodeonline learncodecoursescert yearscode yearscodepro devtype orgsize  \
# 0             NaN                  NaN       NaN          NaN     NaN     NaN
# 1             NaN                  NaN       NaN          NaN     NaN     NaN
#
#   purchaseinfluence buynewtool country              currency  comptotal  \
# 0               NaN        NaN     NaN                   NaN        NaN
# 1               NaN        NaN  Canada  CAD\tCanadian dollar        NaN
#
#   compfreq languagehaveworkedwith languagewanttoworkwith  \
# ...

# %%
df.columns
# Out:
# Index(['responseid', 'mainbranch', 'employment', 'remotework',
#        'codingactivities', 'edlevel', 'learncode', 'learncodeonline',
#        'learncodecoursescert', 'yearscode', 'yearscodepro', 'devtype',
#        'orgsize', 'purchaseinfluence', 'buynewtool', 'country', 'currency',
#        'comptotal', 'compfreq', 'languagehaveworkedwith',
#        'languagewanttoworkwith', 'databasehaveworkedwith',
#        'databasewanttoworkwith', 'platformhaveworkedwith',
#        'platformwanttoworkwith', 'webframehaveworkedwith',
#        'webframewanttoworkwith', 'misctechhaveworkedwith',
#        'misctechwanttoworkwith', 'toolstechhaveworkedwith',
#        'toolstechwanttoworkwith', 'newcollabtoolshaveworkedwith',
#        'newcollabtoolswanttoworkwith', 'opsysprofessional use',
#        'opsyspersonal use', 'versioncontrolsystem', 'vcinteraction',
#        'vchostingpersonal use', 'vchostingprofessional use',
#        'officestackasynchaveworkedwith', 'officestackasyncwanttoworkwith',
# ...

# %%
# https://cmdlinetips.com/2020/07/cleaning_up_pandas-column-names/#google_vignette

# %% [markdown]
# - let's try to understand the more about the data..

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   responseid                      73268 non-null  int64
#  1   mainbranch                      73268 non-null  object
#  2   employment                      71709 non-null  object
#  3   remotework                      58958 non-null  object
#  4   codingactivities                58899 non-null  object
#  5   edlevel                         71571 non-null  object
#  6   learncode                       71580 non-null  object
#  7   learncodeonline                 50685 non-null  object
#  8   learncodecoursescert            29389 non-null  object
#  9   yearscode                       71331 non-null  object
#  10  yearscodepro                    51833 non-null  object
#  11  devtype                         61302 non-null  object
# ...

# %% [markdown]
# #### Observation
#   1. Out of 79 columns 73 are object data type
#   1. one is integer data type
#   1. five is float data type

# %%
#let's see how many duplicate values present in our dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Our data has no duplicated values**

# %%
df.dtypes
# Out:
# responseid               int64
# mainbranch              object
# employment              object
# remotework              object
# codingactivities        object
#                         ...
# truefalse2              object
# truefalse3              object
# surveylength            object
# surveyease              object
# convertedcompyearly    float64
# Length: 79, dtype: object

# %%
df.describe()
# Out:
#          responseid     comptotal  vchostingpersonal use  \
# count  73268.000000  3.842200e+04                    0.0
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        vchostingprofessional use       workexp  convertedcompyearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         3.583200e+04
# ...

# %%
df.describe().T
# Out:
#                              count          mean           std  min       25%  \
# responseid                 73268.0  3.663450e+04  2.115079e+04  1.0  18317.75
# comptotal                  38422.0  2.342434e+52  4.591478e+54  0.0  30000.00
# vchostingpersonal use          0.0           NaN           NaN  NaN       NaN
# vchostingprofessional use      0.0           NaN           NaN  NaN       NaN
# workexp                    36769.0  1.024238e+01  8.706850e+00  0.0      4.00
# convertedcompyearly        38071.0  1.707613e+05  7.814132e+05  1.0  35832.00
#
#                                50%        75%           max
# responseid                 36634.5   54951.25  7.326800e+04
# comptotal                  77500.0  154000.00  9.000000e+56
# vchostingpersonal use          NaN        NaN           NaN
# vchostingprofessional use      NaN        NaN           NaN
# workexp                        8.0      15.00  5.000000e+01
# convertedcompyearly        67845.0  120000.00  5.000000e+07

# %%
df.isnull().sum()
# Out:
# responseid                 0
# mainbranch                 0
# employment              1559
# remotework             14310
# codingactivities       14369
#                        ...
# truefalse2             37553
# truefalse3             37519
# surveylength            2824
# surveyease              2760
# convertedcompyearly    35197
# Length: 79, dtype: int64

# %%
df[df.columns[df.isnull().any()]]
# Out:
#                                               employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  remotework  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...

# %%
df.isna().any()
# Out:
# responseid             False
# mainbranch             False
# employment              True
# remotework              True
# codingactivities        True
#                        ...
# truefalse2              True
# truefalse3              True
# surveylength            True
# surveyease              True
# convertedcompyearly     True
# Length: 79, dtype: bool

# %%
df[df.columns[df.isna().any()]]
# Out:
#                                               employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  remotework  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...

# %%
# saprate catigorical and numerical features
catigorical_features = df.select_dtypes(include="object").columns
numerical_features = df.select_dtypes(exclude="object").columns

# %%
catigorical_features
# Out:
# Index(['mainbranch', 'employment', 'remotework', 'codingactivities', 'edlevel',
#        'learncode', 'learncodeonline', 'learncodecoursescert', 'yearscode',
#        'yearscodepro', 'devtype', 'orgsize', 'purchaseinfluence', 'buynewtool',
#        'country', 'currency', 'compfreq', 'languagehaveworkedwith',
#        'languagewanttoworkwith', 'databasehaveworkedwith',
#        'databasewanttoworkwith', 'platformhaveworkedwith',
#        'platformwanttoworkwith', 'webframehaveworkedwith',
#        'webframewanttoworkwith', 'misctechhaveworkedwith',
#        'misctechwanttoworkwith', 'toolstechhaveworkedwith',
#        'toolstechwanttoworkwith', 'newcollabtoolshaveworkedwith',
#        'newcollabtoolswanttoworkwith', 'opsysprofessional use',
#        'opsyspersonal use', 'versioncontrolsystem', 'vcinteraction',
#        'officestackasynchaveworkedwith', 'officestackasyncwanttoworkwith',
#        'officestacksynchaveworkedwith', 'officestacksyncwanttoworkwith',
# ...

# %%
catigorical_features.shape
# Out:
# (73,)

# %%
numerical_features
# Out:
# Index(['responseid', 'comptotal', 'vchostingpersonal use',
#        'vchostingprofessional use', 'workexp', 'convertedcompyearly'],
#       dtype='object')

# %%
numerical_features.shape
# Out:
# (6,)

# %%
# fetch the unique value from catigorical data
for i in catigorical_features:
    print(i,df[i].unique())
    
    print()
    print("*****************************Seperated_Columns********************************")
    print()
# Out:
# mainbranch ['None of these' 'I am a developer by profession'
#  'I am not primarily a developer, but I write code sometimes as part of my work'
#  'I code primarily as a hobby' 'I am learning to code'
#  'I used to be a developer by profession, but no longer am']
#
# *****************************Seperated_Columns********************************
#
# employment [nan 'Employed, full-time' 'Student, full-time' 'Student, part-time'
#  'Not employed, but looking for work'
#  'Independent contractor, freelancer, or self-employed'
#  'Employed, full-time;Independent contractor, freelancer, or self-employed'
#  'Employed, part-time' 'Student, part-time;Employed, part-time'
#  'Not employed, and not looking for work'
#  'Student, full-time;Employed, part-time'
#  'Employed, full-time;Student, part-time'
#  'Employed, full-time;Student, full-time'
#  'Student, part-time;Independent contractor, freelancer, or self-employed'
#  'Retired' 'Student, full-time;Not employed, but looking for work'
# ...

# %%
for i in numerical_features:
    print(i,df[i].unique())
    
    print()
    print("*****************************Seperated_Columns********************************")
    print()
# Out:
# responseid [    1     2     3 ... 73266 73267 73268]
#
# *****************************Seperated_Columns********************************
#
# comptotal [     nan   32000.   60000. ... 1038000.   64200.  439000.]
#
# *****************************Seperated_Columns********************************
#
# vchostingpersonal use [nan]
#
# *****************************Seperated_Columns********************************
#
# vchostingprofessional use [nan]
#
# *****************************Seperated_Columns********************************
#
# workexp [nan  6. 14.  5. 15.  4. 23.  9. 22. 21.  3. 28.  7. 12.  8.  2. 20. 27.
#   1. 10. 19. 13. 30. 11. 18. 47. 17. 46. 25. 24. 31.  0. 41. 43. 40. 16.
#  42. 35. 32. 34. 26. 36. 38. 29. 33. 44. 37. 50. 45. 39. 48. 49.]
#
# *****************************Seperated_Columns********************************
#
# convertedcompyearly [    nan  40205. 215232. ...  16203.  43324. 110245.]
#
# ...

# %%
#Let's create some new features with help of existing feature:
features =[]
dtypes =[]
count =[]
uniques =[]
missing = []
missing_percentage=[]

for j in df.columns:
    features.append(j)
    count.append(len(df[j]))
    missing.append(df[j].isnull().sum())
    uniques.append(df[j].nunique())
    dtypes.append(df[j].dtypes)
    missing_percentage.append((df[j].isnull().sum()/df.shape[0])*100)
    
dataframe = pd.DataFrame({'feature':features,
                         'count':count,
                         'missing':missing,
                         'nunique':uniques,
                         'dtypes':dtypes,
                         'missing_percentage':missing_percentage})

dataframe.set_index('feature')
# Out:
#                      count  missing  nunique   dtypes  missing_percentage
# feature
# responseid           73268        0    73268    int64            0.000000
# mainbranch           73268        0        6   object            0.000000
# employment           73268     1559      103   object            2.127805
# remotework           73268    14310        3   object           19.531037
# codingactivities     73268    14369       63   object           19.611563
# ...                    ...      ...      ...      ...                 ...
# truefalse2           73268    37553        2   object           51.254299
# truefalse3           73268    37519        2   object           51.207894
# surveylength         73268     2824        3   object            3.854343
# surveyease           73268     2760        3   object            3.766992
# convertedcompyearly  73268    35197     7909  float64           48.038707
#
# [79 rows x 5 columns]

# %%
for j in catigorical_features:
    print(j,df[j].value_counts())
    print()
    print('-----------------------------------------------------------------------------------')
    print()
# Out:
# mainbranch I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: mainbranch, dtype: int64
#
# -----------------------------------------------------------------------------------
#
# employment Employed, full-time                                                                                                                    42962
# Student, full-time                                                                                                                      6756
# ...
