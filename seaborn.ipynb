# %% [markdown]
# # Seaborn Tutorial

# %%
#for reference : https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#correlation with heatnap
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #jointplot - allows to study the relationship between two numeric variables. The centrail chart display their correlation. It is usually a scatterplot, a hexbinplot, a 2D hietogram or 2D density plot

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.distplot(df['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df['tip'],kde=False,bins=10)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
#categorical Plots
sns.countplot(y='sex',data=df) #by default it takes as x-axis
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %%
sns.countplot('smoker',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot('day',data=df,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
#in barplot we have to give both x and y value
sns.barplot(x='sex',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x='sex',y='size',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='size'>

# %% [markdown]
# ### Box plot
# A box or whisker plot is a graph that represents information from a five number summary

# %%
sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df)#doing on its own
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df, orient ='v')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='day',y='total_bill',data=df,palette='rainbow',hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### violin plot
# It helps us to see both the distribution of data in terms of KDE and boxplot

# %%
sns.violinplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x='total_bill',y='day',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
numeric_data = df.select_dtypes(include=[np.number])
categorical_data = df.select_dtypes(exclude=[np.number])

# %%
numeric_data.head(2)
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3

# %%
categorical_data.head(2)
# Out:
#       sex smoker  day    time
# 0  Female     No  Sun  Dinner
# 1    Male     No  Sun  Dinner

# %%
df1 = df.select_dtypes([np.int,np.float])
for i, col in enumerate(df1.columns):
    plt.figure(i)
    plt.style.use('ggplot')
    sns.countplot(x=col, data=df1)
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %%
for i in numeric_data:
    sns.displot(data=df,x=i,height=4,aspect=2,color='#158685')

# %%
categorical_data
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
for i in categorical_data:
    sns.countplot(data=df,x=i,color='yellow',palette='deep')
    plt.xticks( rotation=90)
    plt.style.use('ggplot')
    plt.tight_layout()

# %%
#plt.subplots(#no of rows,#no of cols,#total no of plots)
plt.subplots()
sns.countplot('smoker',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
plt.subplots(2, sharex=True, sharey=True)
sns.countplot(x='day',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
#fig is the canvas size
fig, (ax1,ax2) = plt.subplots(1,2)

# %%
numeric_data.head(2)
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
fig.set_facecolor('lightblue')
ax1.set_facecolor('green')
ax2.set_facecolor('yellow')

# %%
fig, axs = plt.subplots(2,2)
fig.set_facecolor('black')
axs[0,0].set_facecolor('lightblue')
axs[0,1].set_facecolor('lightgreen')
axs[1,0].set_facecolor('lightyellow')
axs[1,1].set_facecolor('red')

# %%
pvcap={'Germany':20000,'Japan':19000,"USA":18000,'china':17000}
countries = list(pvcap.keys())
cap = list(pvcap.values())
plt.bar(countries,cap,color='blue',width=0.8)
plt.title('Solar Usage')
plt.xlabel('countreis')
plt.ylabel('capacity')
# Out:
# Text(0, 0.5, 'capacity')

# %%
pvcap={'Germany':20000,'Japan':19000,"USA":18000,'china':17000}
countries = list(pvcap.keys())
cap = list(pvcap.values())
plt.bar(countries,cap,color='blue',width=0.8)
plt.title('Solar Usage')
plt.xlabel('countreis')
plt.ylabel('capacity')
for i, v in enumerate(cap):
    #i is the index v is the value
    plt.text(i, v+1000, str(v), ha='center',weight='bold',size=10)

# %%
numeric_data
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
x=df['total_bill']
y=df['tip']
z=df['size']

# %%
fig, ax = plt.subplots(2,2,figsize=(9,9),sharex='row',sharey='row')
ax[0,1].plot(x,y)
ax[0,1].title.set_text('TIP & size')
ax[0,0].plot(y,z)

# %%
categorical_data.head(2)
# Out:
#       sex smoker  day    time
# 0  Female     No  Sun  Dinner
# 1    Male     No  Sun  Dinner

# %%
columns=['sex','smoker','day','time']
for i in range(0, len(columns)):
    plt.subplot(2,2,i+1)
    sns.countplot(x=df[columns[i]])
    plt.xticks(size=15, rotation=90)
    plt.tight_layout()
